# %%
# %python
print("hello Sundar")

# %%
# %sql
select count(*) from samples.bakehouse.sales_customers

# %%
# %sql
select * from samples.bakehouse.sales_customers LIMIT 10

# %%
# %sql
select count(*) from samples.bakehouse.sales_customers

# %% [markdown]
# #databricks

# %%
# %python

spark.conf.set("fs.azure.account.auth.type", "OAuth")

# %%
df = spark.read.load("abfss://source@ststorageaccount2026.dfs.core.windows.net/Sales.csv")

# %%
df = spark.read.format("csv").load("abfss://source@ststorageaccount2026.dfs.core.windows.net/Sales.csv")

# %%
df.show()

# %%
dbutils.fs.ls("abfss://source@ststorageaccount2026.dfs.core.windows.net")

# %%
dbutils.widgets.text("p_name","sun")

# %%
dbutils.widgets.get("p_name")
